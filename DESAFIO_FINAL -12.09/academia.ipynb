# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



sns.set(style="whitegrid")



plt.figure(figsize=(10,6))
sns.histplot(df['idade'], bins=10, kde=True, color='blue')
plt.title("Distribuição de Idade dos Alunos")
plt.xlabel("Idade")
plt.ylabel("Quantidade")
plt.show()


plt.figure(figsize=(12,6))
sns.barplot(x='tipo_atividade', y='frequencia_semanal_treino', data=df, ci=None, palette='viridis')
plt.title("Frequência Semanal de Treino por Tipo de Atividade")
plt.xlabel("Tipo de Atividade")
plt.ylabel("Frequência Semanal")
plt.xticks(rotation=45)
plt.show()


plt.figure(figsize=(10,6))
sns.scatterplot(x='tempo_medio_exercicio', y='preco_plano', hue='estado', data=df, s=100)
plt.title("Tempo Médio de Exercício x Preço do Plano")
plt.xlabel("Tempo Médio de Exercício (minutos)")
plt.ylabel("Preço do Plano (R$)")
plt.show()



print("Média de idade dos alunos:", df['idade'].mean())
print("Atividade mais popular:", df['tipo_atividade'].mode()[0])


uploaded = files.upload()

df = pd.read_csv("academia_redfit_clean.csv")
print(df.head())
# Out:
# /tmp/ipython-input-2497924736.py:21: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='tipo_atividade', y='frequencia_semanal_treino', data=df, ci=None, palette='viridis')
# /tmp/ipython-input-2497924736.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='tipo_atividade', y='frequencia_semanal_treino', data=df, ci=None, palette='viridis')
# Média de idade dos alunos: 40.811
# Atividade mais popular: Yoga
#      <input type="file" id="files-d776eecd-2616-40eb-9361-3d5b5f4c05ab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d776eecd-2616-40eb-9361-3d5b5f4c05ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
# ...
